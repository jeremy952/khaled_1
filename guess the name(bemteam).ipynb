# %%
import random

# %%
bemteam = [
    
    "nikita","khaled","vlad","danilis","yasa",
    "lee","ruslan","jenna","oscar","dmitry",
    "natasha","bryce","austin","yuri"
]

# %%
while True:
    print("guess the bemteam name members")
    print("Hint: names of members and magers")
    word = random.choice(bemteam)
    letterguesed = list('_'*len(word))
    print(' '.join(letterguesed))
    chance = len(word) + 2
    wrong_guess = []
    while chance > 0:
        guess = input("Enter letter to guess :")
        if not (guess.isalpha()):
            print ("unsupported opration !")
        elif len(guess) > 1:
            print ("Enter only one charactar !")
        elif guess in letterguesed:
            print ("you have already guess that letter !")
        elif guess in word:
            for i, char in enumerate(word):
                if guess == char:
                    letterguesed[i] = char
            print(' '.join(letterguesed))
            
        elif not(guess in wrong_guess):
            chance = chance - 1 
            wrong_guess.append(guess)
            print(f"wrong guessing , you have left {chance}chances !")
        else: 
            print ( "you have already guessed that wrong letter !")
            
            
        if"".join(letterguesed) == word:
            print (" cool ,  look's like a big fan of bemteam \nthat's awsome !!")
            break
            
        if chance <= 0:
            print ("look's like you don't know who is bemteam o_0 ! ")
            print ("go and check our paltforms on social media")
            print (f"it was {word}")
            
            
    play = input(' do you wanna try agian ? (yes/no)')
    if play == 'no':
        break
# Out:
# guess the bemteam name members
# Hint: names of members and magers
# _ _ _ _ _
# Enter letter to guess :b
# wrong guessing , you have left 6chances !
# Enter letter to guess :k
# wrong guessing , you have left 5chances !
# Enter letter to guess :o
# wrong guessing , you have left 4chances !
# Enter letter to guess :r
# wrong guessing , you have left 3chances !
# Enter letter to guess :d
# wrong guessing , you have left 2chances !
# Enter letter to guess :a
# _ _ _ _ a
# Enter letter to guess :j
# j _ _ _ a
# Enter letter to guess :e
# j e _ _ a
# Enter letter to guess :n
# j e n n a
#  cool ,  look's like a big fan of bemteam
# that's awsome !!
#  do you wanna try agian ? (yes/no)n
# guess the bemteam name members
# Hint: names of members and magers
# _ _ _ _ _ _
# Enter letter to guess :n
# _ _ _ _ _ n
# Enter letter to guess :r
# wrong guessing , you have left 7chances !
# Enter letter to guess :a
# a _ _ _ _ n
# Enter letter to guess :u
# a u _ _ _ n
# Enter letter to guess :s
# ...
